# %%
import pandas as pd
import re

# %%
chmfile=pd.read_excel('Comp_Repair_CFM56-5B-2019_Catalog.xls',None)
chmfile2=pd.read_excel('Comp_Repair_CFM56-5B-2019_Catalog.xls')

# %%
sheets=list(chmfile.keys())

# %%
sheets
# Out:
# ['Combustor, HPT', 'Compressor', 'Fan', 'LPT', 'Other Components']

# %%
modelID=chmfile2.columns[2].split()[0]
col=['Model ID','Section','Component/Part Name','Part ID','Place of Repair','Part Nos','Repair Code','Repair Description','Comments','Price']
ChmData=pd.DataFrame(columns=col)
ChmData
# Out:
# Empty DataFrame
# Columns: [Model ID, Section, Component/Part Name, Part ID, Place of Repair, Part Nos, Repair Code, Repair Description, Comments, Price]
# Index: []

# %%
modelID=chmfile2.columns[2].split()[0]
year=chmfile2.columns[2].split()[1]
cmpny_name='GE'

# %%
col_new=['Company Name','Model ID','Section','Part Name','ATA-Capter (Ref No.)','Part ID (Component Code)','Place of Repair','Part Nos','Repair Code','Repair Description','Comments','Repair Type','TAT Days','Price per ea (USD)']
ChmData_new=pd.DataFrame(columns=col_new)
ChmData_new
# Out:
# Empty DataFrame
# Columns: [Company Name, Model ID, Section, Part Name, ATA-Capter (Ref No.), Part ID (Component Code), Place of Repair, Part Nos, Repair Code, Repair Description, Comments, Repair Type, TAT Days, Price per ea (USD)]
# Index: []

# %%
ChmData=pd.DataFrame(columns=col)
for n in range(0,len(sheets)):
    chm=chmfile[sheets[n]]
    section=sheets[n]
    chm.columns=chm.iloc[0]
    chm=chm.drop(0,axis=0)
    chm=chm.reset_index(drop=True)
    chm=chm.fillna('')
    CompIdx=[i for i in chm.index if chm.iloc[i]['Component Code']!='']
    for i in CompIdx:
        partID=chm[chm.columns[0]][i]
        partName=chm[chm.columns[1]][i]
        repSite=chm[chm.columns[2]][i]
        k=i+1
        i+=1
        
        while(chm[chm.columns[1]][k]!=''):
            pNo=chm[chm.columns[1]][k]
            l=i
            #print(pNo)
            while(True):
                #print('in')
                if chm[chm.columns[3]][l]=='' and chm[chm.columns[4]][l]=='':
                    break
                if chm[chm.columns[4]][l].startswith('*'):
                    ChmData['Comments'][len(ChmData)-1]=chm[chm.columns[4]][l]
                else:
                    dataline=[modelID,section,partName,partID,repSite,pNo,chm[chm.columns[3]][l],chm[chm.columns[4]][l],'',chm[chm.columns[6]][l]]
                    ChmData=ChmData.append(pd.Series(dataline,col),ignore_index=True)
                l+=1
                if(l==len(chm)):
                    break
            k+=1
            #print(k)
            if(k==len(chm)):
                break

# %%
ChmData
# Out:
#        Model ID           Section            Component/Part Name Part ID  \
# 0      CFM56-5B    Combustor, HPT  Combustion Chamber Inner Cowl     42A
# 1      CFM56-5B    Combustor, HPT  Combustion Chamber Inner Cowl     42A
# 2      CFM56-5B    Combustor, HPT  Combustion Chamber Inner Cowl     42A
# 3      CFM56-5B    Combustor, HPT  Combustion Chamber Inner Cowl     42A
# 4      CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 5      CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 6      CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 7      CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 8      CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 9      CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 10     CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 11     CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 12     CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 13     CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 14     CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 15     CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 16     CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 17     CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 18     CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 19     CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 20     CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 21     CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 22     CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 23     CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl     42B
# 24     CFM56-5B    Combustor, HPT         HPT Aft Blade Retainer     524
# 25     CFM56-5B    Combustor, HPT         HPT Aft Blade Retainer     524
# 26     CFM56-5B    Combustor, HPT         HPT Aft Blade Retainer     524
# 27     CFM56-5B    Combustor, HPT         HPT Aft Blade Retainer     524
# 28     CFM56-5B    Combustor, HPT         HPT Aft Blade Retainer     524
# 29     CFM56-5B    Combustor, HPT         HPT Aft Blade Retainer     524
# ...         ...               ...                            ...     ...
# 12440  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12441  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12442  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12443  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12444  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12445  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12446  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12447  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12448  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12449  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12450  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12451  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12452  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12453  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12454  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12455  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12456  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12457  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12458  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12459  CFM56-5B  Other Components                 AGB Drive Pads     73R
# 12460  CFM56-5B  Other Components                     Mount Link     M09
# 12461  CFM56-5B  Other Components                     Mount Link     M09
# 12462  CFM56-5B  Other Components                     Mount Link     M09
# 12463  CFM56-5B  Other Components                     Mount Link     M09
# 12464  CFM56-5B  Other Components                     Mount Link     M09
# 12465  CFM56-5B  Other Components                     Mount Link     M09
# 12466  CFM56-5B  Other Components                     Mount Link     M09
# 12467  CFM56-5B  Other Components                     Mount Link     M09
# 12468  CFM56-5B  Other Components                     Mount Link     M09
# 12469  CFM56-5B  Other Components                  No. 3 Bearing     FAG
#
#             Place of Repair       Part Nos Repair Code  \
# 0      Plant 23 - Singapore     9531M11G02
# 1      Plant 23 - Singapore     9531M11G02        R002
# 2      Plant 23 - Singapore     9531M11G02    SB720237
# 3      Plant 23 - Singapore     9531M11G02       CINSP
# 4      Plant 23 - Singapore     2256M26G04       CINSP
# 5      Plant 23 - Singapore     2256M26G04
# 6      Plant 23 - Singapore     2256M26G04        R001
# 7      Plant 23 - Singapore     2256M26G04    SB720327
# 8      Plant 23 - Singapore     2256M26G03       CINSP
# 9      Plant 23 - Singapore     2256M26G03
# 10     Plant 23 - Singapore     2256M26G03        R001
# 11     Plant 23 - Singapore     2256M26G03    SB720327
# 12     Plant 23 - Singapore     1968M68G41       CINSP
# 13     Plant 23 - Singapore     1968M68G41
# 14     Plant 23 - Singapore     1968M68G41        R001
# 15     Plant 23 - Singapore     1968M68G41    SB720327
# 16     Plant 23 - Singapore     1968M41G03       CINSP
# 17     Plant 23 - Singapore     1968M41G03
# 18     Plant 23 - Singapore     1968M41G03        R001
# 19     Plant 23 - Singapore     1968M41G03    SB720327
# 20     Plant 23 - Singapore     1968M59G01       CINSP
# 21     Plant 23 - Singapore     1968M59G01
# 22     Plant 23 - Singapore     1968M59G01        R001
# 23     Plant 23 - Singapore     1968M59G01    SB720327
# 24                     ACSC     2410M51P01        R002
# 25                     ACSC     2410M51P01       CINSP
# 26                     ACSC     2410M51P01        R003
# 27                     ACSC     2002M15P01        R002
# 28                     ACSC     2002M15P01       CINSP
# 29                     ACSC     2002M15P01        R003
# ...                     ...            ...         ...
# 12440                 Wales  305-139-203-0
# 12441                 Wales  305-139-203-0       CINSP
# 12442                 Wales  305-139-203-0        R001
# 12443                 Wales  305-139-203-0        R002
# 12444                 Wales  305-139-203-0        R007
# 12445                 Wales  305-139-002-0
# 12446                 Wales  305-139-002-0       CINSP
# 12447                 Wales  305-139-002-0        R001
# 12448                 Wales  305-139-002-0        R002
# 12449                 Wales  305-139-002-0        R007
# 12450                 Wales  305-140-001-0
# 12451                 Wales  305-140-001-0       CINSP
# 12452                 Wales  305-140-001-0        R001
# 12453                 Wales  305-140-001-0        R002
# 12454                 Wales  305-140-001-0        R007
# 12455                 Wales  305-138-805-0
# 12456                 Wales  305-138-805-0       CINSP
# 12457                 Wales  305-138-805-0        R001
# 12458                 Wales  305-138-805-0        R002
# 12459                 Wales  305-138-805-0        R007
# 12460                 Wales  340-168-501-0        R010
# 12461                 Wales  305-356-620-0        R010
# 12462                 Wales  305-356-606-0        R010
# 12463                 Wales  305-356-605-0        R010
# 12464                 Wales  305-356-604-0        R010
# 12465                 Wales  301-360-020-0        R010
# 12466                 Wales  301-360-006-0        R010
# 12467                 Wales  301-360-005-0        R010
# 12468                 Wales  301-360-004-0        R010
# 12469                  ACSC     1364M91P02        R002
#
#                                       Repair Description  \
# 0                                        Standard Repair
# 1                                 Weld repair and resize
# 2           Combustor Chamber Inner Cowl Bolt Inspection
# 3                   Clean and serviceability inspection*
# 4                   Clean and serviceability inspection*
# 5                                        Standard Repair
# 6                                 Weld repair and resize
# 7       Introduction of New Outer Cowl with Increased...
# 8                   Clean and serviceability inspection*
# 9                                        Standard Repair
# 10                                Weld repair and resize
# 11      Introduction of New Outer Cowl with Increased...
# 12                  Clean and serviceability inspection*
# 13                                       Standard Repair
# 14                                Weld repair and resize
# 15      Introduction of New Outer Cowl with Increased...
# 16                  Clean and serviceability inspection*
# 17                                       Standard Repair
# 18                                Weld repair and resize
# 19      Introduction of New Outer Cowl with Increased...
# 20                  Clean and serviceability inspection*
# 21                                       Standard Repair
# 22                                Weld repair and resize
# 23      Introduction of New Outer Cowl with Increased...
# 24                                    Repair dimension D
# 25                  Clean and serviceability inspection*
# 26                    Thermal Spray Repair of Diameter E
# 27                                    Repair dimension D
# 28                  Clean and serviceability inspection*
# 29                    Thermal Spray Repair of Diameter E
# ...                                                  ...
# 12440                                    Standard Repair
# 12441                Clean and serviceability inspection
# 12442                           Replace key-locked studs
# 12443                        Replace ring-locked nipples
# 12444                                   Coating touch-up
# 12445                                    Standard Repair
# 12446                Clean and serviceability inspection
# 12447                           Replace key-locked studs
# 12448                        Replace ring-locked nipples
# 12449                                   Coating touch-up
# 12450                                    Standard Repair
# 12451                Clean and serviceability inspection
# 12452                           Replace key-locked studs
# 12453                        Replace ring-locked nipples
# 12454                                   Coating touch-up
# 12455                                    Standard Repair
# 12456                Clean and serviceability inspection
# 12457                           Replace key-locked studs
# 12458                        Replace ring-locked nipples
# 12459                                   Coating touch-up
# 12460                              Replace spherical brg
# 12461                              Replace spherical brg
# 12462                              Replace spherical brg
# 12463                              Replace spherical brg
# 12464                              Replace spherical brg
# 12465                              Replace spherical brg
# 12466                              Replace spherical brg
# 12467                              Replace spherical brg
# 12468                              Replace spherical brg
# 12469                                     Bearing Repair
#
#                                                 Comments   Price
# 0                                                           1785
# 1
# 2
# 3      *Note: If part fails serviceability inspection...     277
# 4      *Note: If part fails serviceability inspection...     277
# 5                                                           1780
# 6
# 7
# 8      *Note: If part fails serviceability inspection...     277
# 9                                                           1780
# 10
# 11
# 12     *Note: If part fails serviceability inspection...     277
# 13                                                          1780
# 14
# 15
# 16     *Note: If part fails serviceability inspection...     277
# 17                                                          1780
# 18
# 19
# 20     *Note: If part fails serviceability inspection...     277
# 21                                                          1780
# 22
# 23
# 24                                                        +17910
# 25     *Note: If part fails serviceability inspection...    1580
# 26                                                        +16760
# 27                                                        +17910
# 28     *Note: If part fails serviceability inspection...    1580
# 29                                                        +16760
# ...                                                  ...     ...
# 12440                                                       2630
# 12441
# 12442
# 12443
# 12444
# 12445                                                       2630
# 12446
# 12447
# 12448
# 12449
# 12450                                                       2630
# 12451
# 12452
# 12453
# 12454
# 12455                                                       2630
# 12456
# 12457
# 12458
# 12459
# 12460                                                       3625
# 12461                                                       3625
# 12462                                                       3625
# 12463                                                       3625
# 12464                                                       3625
# 12465                                                       3625
# 12466                                                       3625
# 12467                                                       3625
# 12468                                                       3625
# 12469                                                      25430
#
# [12470 rows x 10 columns]

# %%
ChmData.to_excel('GE_'+modelID+'.xlsx',index = None)

# %%
#New Formatting according to the new tempalte
ChmData_new=pd.DataFrame(columns=col_new)
for n in range(0,len(sheets)):
    chm=chmfile[sheets[n]]
    section=sheets[n]
    chm.columns=chm.iloc[0]
    chm=chm.drop(0,axis=0)
    chm=chm.reset_index(drop=True)
    chm=chm.fillna('')
    CompIdx=[i for i in chm.index if chm.iloc[i]['Component Code']!='']
    for i in CompIdx:
        partID=chm[chm.columns[0]][i]
        partName=chm[chm.columns[1]][i]
        repSite=chm[chm.columns[2]][i]
        ATA_No=chm[chm.columns[3]][i]
        k=i+1
        i+=1
        
        while(chm[chm.columns[1]][k]!=''):
            pNo=chm[chm.columns[1]][k]
            l=i
            #print(pNo)
            while(True):
                #print('in')
                if chm[chm.columns[3]][l]=='' and chm[chm.columns[4]][l]=='':
                    break
                if chm[chm.columns[4]][l].startswith('*'):
                    ChmData_new['Comments'][len(ChmData_new)-1]=chm[chm.columns[4]][l]
                else:
                    repcode=chm[chm.columns[3]][l]
                    reptype='Non-OEM'
                    if re.match(r'^R',repcode):
                        repcode=repcode[1:]
                        reptype='OEM'
                    dataline=[cmpny_name,modelID,section,partName,ATA_No,partID,repSite,pNo,repcode,chm[chm.columns[4]][l],'',reptype,re.sub(r'[+]', '',chm[chm.columns[5]][l]),re.sub(r'[+]', '',chm[chm.columns[6]][l])]
                    ChmData_new=ChmData_new.append(pd.Series(dataline,col_new),ignore_index=True)
                l+=1
                if(l==len(chm)):
                    break
            k+=1
            #print(k)
            if(k==len(chm)):
                break

# %%
ChmData_new.to_excel('GE_'+modelID+'_dummyData.xlsx',index = None)

# %%
ChmData_new
# Out:
#       Company Name  Model ID           Section                      Part Name  \
# 0               GE  CFM56-5B    Combustor, HPT  Combustion Chamber Inner Cowl
# 1               GE  CFM56-5B    Combustor, HPT  Combustion Chamber Inner Cowl
# 2               GE  CFM56-5B    Combustor, HPT  Combustion Chamber Inner Cowl
# 3               GE  CFM56-5B    Combustor, HPT  Combustion Chamber Inner Cowl
# 4               GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 5               GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 6               GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 7               GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 8               GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 9               GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 10              GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 11              GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 12              GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 13              GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 14              GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 15              GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 16              GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 17              GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 18              GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 19              GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 20              GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 21              GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 22              GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 23              GE  CFM56-5B    Combustor, HPT  Combustion Chamber Outer Cowl
# 24              GE  CFM56-5B    Combustor, HPT         HPT Aft Blade Retainer
# 25              GE  CFM56-5B    Combustor, HPT         HPT Aft Blade Retainer
# 26              GE  CFM56-5B    Combustor, HPT         HPT Aft Blade Retainer
# 27              GE  CFM56-5B    Combustor, HPT         HPT Aft Blade Retainer
# 28              GE  CFM56-5B    Combustor, HPT         HPT Aft Blade Retainer
# 29              GE  CFM56-5B    Combustor, HPT         HPT Aft Blade Retainer
# ...            ...       ...               ...                            ...
# 12440           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12441           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12442           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12443           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12444           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12445           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12446           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12447           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12448           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12449           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12450           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12451           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12452           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12453           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12454           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12455           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12456           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12457           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12458           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12459           GE  CFM56-5B  Other Components                 AGB Drive Pads
# 12460           GE  CFM56-5B  Other Components                     Mount Link
# 12461           GE  CFM56-5B  Other Components                     Mount Link
# 12462           GE  CFM56-5B  Other Components                     Mount Link
# 12463           GE  CFM56-5B  Other Components                     Mount Link
# 12464           GE  CFM56-5B  Other Components                     Mount Link
# 12465           GE  CFM56-5B  Other Components                     Mount Link
# 12466           GE  CFM56-5B  Other Components                     Mount Link
# 12467           GE  CFM56-5B  Other Components                     Mount Link
# 12468           GE  CFM56-5B  Other Components                     Mount Link
# 12469           GE  CFM56-5B  Other Components                  No. 3 Bearing
#
#       ATA-Capter (Ref No.) Part ID (Component Code)       Place of Repair  \
# 0                 72-42-01                      42A  Plant 23 - Singapore
# 1                 72-42-01                      42A  Plant 23 - Singapore
# 2                 72-42-01                      42A  Plant 23 - Singapore
# 3                 72-42-01                      42A  Plant 23 - Singapore
# 4                 72-42-01                      42B  Plant 23 - Singapore
# 5                 72-42-01                      42B  Plant 23 - Singapore
# 6                 72-42-01                      42B  Plant 23 - Singapore
# 7                 72-42-01                      42B  Plant 23 - Singapore
# 8                 72-42-01                      42B  Plant 23 - Singapore
# 9                 72-42-01                      42B  Plant 23 - Singapore
# 10                72-42-01                      42B  Plant 23 - Singapore
# 11                72-42-01                      42B  Plant 23 - Singapore
# 12                72-42-01                      42B  Plant 23 - Singapore
# 13                72-42-01                      42B  Plant 23 - Singapore
# 14                72-42-01                      42B  Plant 23 - Singapore
# 15                72-42-01                      42B  Plant 23 - Singapore
# 16                72-42-01                      42B  Plant 23 - Singapore
# 17                72-42-01                      42B  Plant 23 - Singapore
# 18                72-42-01                      42B  Plant 23 - Singapore
# 19                72-42-01                      42B  Plant 23 - Singapore
# 20                72-42-01                      42B  Plant 23 - Singapore
# 21                72-42-01                      42B  Plant 23 - Singapore
# 22                72-42-01                      42B  Plant 23 - Singapore
# 23                72-42-01                      42B  Plant 23 - Singapore
# 24                72-52-06                      524                  ACSC
# 25                72-52-06                      524                  ACSC
# 26                72-52-06                      524                  ACSC
# 27                72-52-06                      524                  ACSC
# 28                72-52-06                      524                  ACSC
# 29                72-52-06                      524                  ACSC
# ...                    ...                      ...                   ...
# 12440             72-62-05                      73R                 Wales
# 12441             72-62-05                      73R                 Wales
# 12442             72-62-05                      73R                 Wales
# 12443             72-62-05                      73R                 Wales
# 12444             72-62-05                      73R                 Wales
# 12445             72-62-05                      73R                 Wales
# 12446             72-62-05                      73R                 Wales
# 12447             72-62-05                      73R                 Wales
# 12448             72-62-05                      73R                 Wales
# 12449             72-62-05                      73R                 Wales
# 12450             72-62-05                      73R                 Wales
# 12451             72-62-05                      73R                 Wales
# 12452             72-62-05                      73R                 Wales
# 12453             72-62-05                      73R                 Wales
# 12454             72-62-05                      73R                 Wales
# 12455             72-62-05                      73R                 Wales
# 12456             72-62-05                      73R                 Wales
# 12457             72-62-05                      73R                 Wales
# 12458             72-62-05                      73R                 Wales
# 12459             72-62-05                      73R                 Wales
# 12460             72-09-04                      M09                 Wales
# 12461             72-09-04                      M09                 Wales
# 12462             72-09-04                      M09                 Wales
# 12463             72-09-04                      M09                 Wales
# 12464             72-09-04                      M09                 Wales
# 12465             72-09-04                      M09                 Wales
# 12466             72-09-04                      M09                 Wales
# 12467             72-09-04                      M09                 Wales
# 12468             72-09-04                      M09                 Wales
# 12469             72-21-09                      FAG                  ACSC
#
#             Part Nos Repair Code  \
# 0         9531M11G02
# 1         9531M11G02         002
# 2         9531M11G02    SB720237
# 3         9531M11G02       CINSP
# 4         2256M26G04       CINSP
# 5         2256M26G04
# 6         2256M26G04         001
# 7         2256M26G04    SB720327
# 8         2256M26G03       CINSP
# 9         2256M26G03
# 10        2256M26G03         001
# 11        2256M26G03    SB720327
# 12        1968M68G41       CINSP
# 13        1968M68G41
# 14        1968M68G41         001
# 15        1968M68G41    SB720327
# 16        1968M41G03       CINSP
# 17        1968M41G03
# 18        1968M41G03         001
# 19        1968M41G03    SB720327
# 20        1968M59G01       CINSP
# 21        1968M59G01
# 22        1968M59G01         001
# 23        1968M59G01    SB720327
# 24        2410M51P01         002
# 25        2410M51P01       CINSP
# 26        2410M51P01         003
# 27        2002M15P01         002
# 28        2002M15P01       CINSP
# 29        2002M15P01         003
# ...              ...         ...
# 12440  305-139-203-0
# 12441  305-139-203-0       CINSP
# 12442  305-139-203-0         001
# 12443  305-139-203-0         002
# 12444  305-139-203-0         007
# 12445  305-139-002-0
# 12446  305-139-002-0       CINSP
# 12447  305-139-002-0         001
# 12448  305-139-002-0         002
# 12449  305-139-002-0         007
# 12450  305-140-001-0
# 12451  305-140-001-0       CINSP
# 12452  305-140-001-0         001
# 12453  305-140-001-0         002
# 12454  305-140-001-0         007
# 12455  305-138-805-0
# 12456  305-138-805-0       CINSP
# 12457  305-138-805-0         001
# 12458  305-138-805-0         002
# 12459  305-138-805-0         007
# 12460  340-168-501-0         010
# 12461  305-356-620-0         010
# 12462  305-356-606-0         010
# 12463  305-356-605-0         010
# 12464  305-356-604-0         010
# 12465  301-360-020-0         010
# 12466  301-360-006-0         010
# 12467  301-360-005-0         010
# 12468  301-360-004-0         010
# 12469     1364M91P02         002
#
#                                       Repair Description  \
# 0                                        Standard Repair
# 1                                 Weld repair and resize
# 2           Combustor Chamber Inner Cowl Bolt Inspection
# 3                   Clean and serviceability inspection*
# 4                   Clean and serviceability inspection*
# 5                                        Standard Repair
# 6                                 Weld repair and resize
# 7       Introduction of New Outer Cowl with Increased...
# 8                   Clean and serviceability inspection*
# 9                                        Standard Repair
# 10                                Weld repair and resize
# 11      Introduction of New Outer Cowl with Increased...
# 12                  Clean and serviceability inspection*
# 13                                       Standard Repair
# 14                                Weld repair and resize
# 15      Introduction of New Outer Cowl with Increased...
# 16                  Clean and serviceability inspection*
# 17                                       Standard Repair
# 18                                Weld repair and resize
# 19      Introduction of New Outer Cowl with Increased...
# 20                  Clean and serviceability inspection*
# 21                                       Standard Repair
# 22                                Weld repair and resize
# 23      Introduction of New Outer Cowl with Increased...
# 24                                    Repair dimension D
# 25                  Clean and serviceability inspection*
# 26                    Thermal Spray Repair of Diameter E
# 27                                    Repair dimension D
# 28                  Clean and serviceability inspection*
# 29                    Thermal Spray Repair of Diameter E
# ...                                                  ...
# 12440                                    Standard Repair
# 12441                Clean and serviceability inspection
# 12442                           Replace key-locked studs
# 12443                        Replace ring-locked nipples
# 12444                                   Coating touch-up
# 12445                                    Standard Repair
# 12446                Clean and serviceability inspection
# 12447                           Replace key-locked studs
# 12448                        Replace ring-locked nipples
# 12449                                   Coating touch-up
# 12450                                    Standard Repair
# 12451                Clean and serviceability inspection
# 12452                           Replace key-locked studs
# 12453                        Replace ring-locked nipples
# 12454                                   Coating touch-up
# 12455                                    Standard Repair
# 12456                Clean and serviceability inspection
# 12457                           Replace key-locked studs
# 12458                        Replace ring-locked nipples
# 12459                                   Coating touch-up
# 12460                              Replace spherical brg
# 12461                              Replace spherical brg
# 12462                              Replace spherical brg
# 12463                              Replace spherical brg
# 12464                              Replace spherical brg
# 12465                              Replace spherical brg
# 12466                              Replace spherical brg
# 12467                              Replace spherical brg
# 12468                              Replace spherical brg
# 12469                                     Bearing Repair
#
#                                                 Comments Repair Type TAT Days  \
# 0                                                            Non-OEM       14
# 1                                                                OEM
# 2                                                            Non-OEM
# 3      *Note: If part fails serviceability inspection...     Non-OEM        0
# 4      *Note: If part fails serviceability inspection...     Non-OEM        7
# 5                                                            Non-OEM       14
# 6                                                                OEM
# 7                                                            Non-OEM
# 8      *Note: If part fails serviceability inspection...     Non-OEM        7
# 9                                                            Non-OEM       14
# 10                                                               OEM
# 11                                                           Non-OEM
# 12     *Note: If part fails serviceability inspection...     Non-OEM        7
# 13                                                           Non-OEM       14
# 14                                                               OEM
# 15                                                           Non-OEM
# 16     *Note: If part fails serviceability inspection...     Non-OEM        7
# 17                                                           Non-OEM       14
# 18                                                               OEM
# 19                                                           Non-OEM
# 20     *Note: If part fails serviceability inspection...     Non-OEM        7
# 21                                                           Non-OEM       14
# 22                                                               OEM
# 23                                                           Non-OEM
# 24                                                               OEM        7
# 25     *Note: If part fails serviceability inspection...     Non-OEM       14
# 26                                                               OEM        7
# 27                                                               OEM        7
# 28     *Note: If part fails serviceability inspection...     Non-OEM       14
# 29                                                               OEM        7
# ...                                                  ...         ...      ...
# 12440                                                        Non-OEM       21
# 12441                                                        Non-OEM
# 12442                                                            OEM
# 12443                                                            OEM
# 12444                                                            OEM
# 12445                                                        Non-OEM       21
# 12446                                                        Non-OEM
# 12447                                                            OEM
# 12448                                                            OEM
# 12449                                                            OEM
# 12450                                                        Non-OEM       21
# 12451                                                        Non-OEM
# 12452                                                            OEM
# 12453                                                            OEM
# 12454                                                            OEM
# 12455                                                        Non-OEM       21
# 12456                                                        Non-OEM
# 12457                                                            OEM
# 12458                                                            OEM
# 12459                                                            OEM
# 12460                                                            OEM       35
# 12461                                                            OEM       35
# 12462                                                            OEM       35
# 12463                                                            OEM       35
# 12464                                                            OEM       35
# 12465                                                            OEM       35
# 12466                                                            OEM       35
# 12467                                                            OEM       35
# 12468                                                            OEM       35
# 12469                                                            OEM       21
#
#       Price per ea (USD)
# 0                   1785
# 1
# 2
# 3                    277
# 4                    277
# 5                   1780
# 6
# 7
# 8                    277
# 9                   1780
# 10
# 11
# 12                   277
# 13                  1780
# 14
# 15
# 16                   277
# 17                  1780
# 18
# 19
# 20                   277
# 21                  1780
# 22
# 23
# 24                 17910
# 25                  1580
# 26                 16760
# 27                 17910
# 28                  1580
# 29                 16760
# ...                  ...
# 12440               2630
# 12441
# 12442
# 12443
# 12444
# 12445               2630
# 12446
# 12447
# 12448
# 12449
# 12450               2630
# 12451
# 12452
# 12453
# 12454
# 12455               2630
# 12456
# 12457
# 12458
# 12459
# 12460               3625
# 12461               3625
# 12462               3625
# 12463               3625
# 12464               3625
# 12465               3625
# 12466               3625
# 12467               3625
# 12468               3625
# 12469              25430
#
# [12470 rows x 14 columns]

# %%
col_new_flags=['Year','Company Name','Model ID','Section','Part Name','ATA-Capter (Ref No.)','Part ID (Component Code)','Place of Repair','Part Nos','Repair Code','Repair Description','Comments','Repair Type','TAT Days','Price per ea (USD)','pack_flag','Service Count']
ChmData_new_flags=pd.DataFrame(columns=col_new_flags)
ChmData_new_flags
# Out:
# Empty DataFrame
# Columns: [Year, Company Name, Model ID, Section, Part Name, ATA-Capter (Ref No.), Part ID (Component Code), Place of Repair, Part Nos, Repair Code, Repair Description, Comments, Repair Type, TAT Days, Price per ea (USD), pack_flag, Service Count]
# Index: []

# %%
#New Formatting for Packages & services along with flags
ChmData_new_flags=pd.DataFrame(columns=col_new_flags)
for n in range(0,len(sheets)):
    chm=chmfile[sheets[n]]
    section=sheets[n]
    chm.columns=chm.iloc[0]
    chm=chm.drop(0,axis=0)
    chm=chm.reset_index(drop=True)
    chm=chm.fillna('')
    CompIdx=[i for i in chm.index if chm.iloc[i]['Component Code']!='']
    for i in CompIdx:
        partID=chm[chm.columns[0]][i]
        partName=chm[chm.columns[1]][i]
        repSite=chm[chm.columns[2]][i]
        ATA_No=chm[chm.columns[3]][i]
        k=i+1
        i+=1
        
        while(chm[chm.columns[1]][k]!=''):
            pNo=chm[chm.columns[1]][k]
            l=i
            #print(pNo)
            while(True):
                #print('in')
                if chm[chm.columns[3]][l]=='' and chm[chm.columns[4]][l]=='':
                    break
                if chm[chm.columns[4]][l].startswith('*'):
                    ChmData_new_flags['Comments'][len(ChmData_new_flags)-1]=chm[chm.columns[4]][l]
                elif chm[chm.columns[3]][l]=='' and chm[chm.columns[4]][l]!='':
                    repcode=chm[chm.columns[4]][l]
                    repDesc=''
                    reptype=''
                    tatDays=re.sub(r'[+]', '',chm[chm.columns[5]][l])
                    price=re.sub(r'[+]', '',chm[chm.columns[6]][l])
                    count=0
                    l+=1
                    if chm[chm.columns[4]][l].startswith('*'):
                        ChmData_new_flags['Comments'][len(ChmData_new_flags)-1]=chm[chm.columns[4]][l]
                        l+=1
                    while(chm[chm.columns[3]][l]!=''):
                        repc=chm[chm.columns[3]][l]
                        rept='Non-OEM'
                        if re.match(r'^R',repc):
                            repc=repc[1:]
                            rept='OEM'
                        repDesc+=repc+' : '+chm[chm.columns[4]][l]+'\n'
                        reptype+=rept+'\n'
                        count+=1
                        l+=1    
                    pck_flag=1
                    dataline=[year,cmpny_name,modelID,section,partName,ATA_No,partID,repSite,pNo,repcode,repDesc,'',reptype,tatDays,price,pck_flag,count]
                    ChmData_new_flags=ChmData_new_flags.append(pd.Series(dataline,col_new_flags),ignore_index=True)
                    l-=1
                else:
                    repcode=chm[chm.columns[3]][l]
                    reptype='Non-OEM'
                    repDesc=repcode+' : '+chm[chm.columns[4]][l]
                    pck_flag=0
                    if re.match(r'^R',repcode):
                        repcode=repcode[1:]
                        reptype='OEM'
                    dataline=[year,cmpny_name,modelID,section,partName,ATA_No,partID,repSite,pNo,repcode,repDesc,'',reptype,re.sub(r'[+]', '',chm[chm.columns[5]][l]),re.sub(r'[+]', '',chm[chm.columns[6]][l]),pck_flag,1]
                    ChmData_new_flags=ChmData_new_flags.append(pd.Series(dataline,col_new_flags),ignore_index=True)
                l+=1
                if(l==len(chm)):
                    break
            k+=1
            #print(k)
            if(k==len(chm)):
                break

# %%
ChmData_new_flags.iloc[753]
# Out:
# Year                                          2019
# Company Name                                    GE
# Model ID                                  CFM56-5B
# Section                             Combustor, HPT
# Part Name                      Rear Stator Support
# ATA-Capter (Ref No.)                      72-41-07
# Part ID (Component Code)                       332
# Place of Repair                               ACSC
# Part Nos                                1993M20G01
# Repair Code                                    001
# Repair Description          R001 : Restore flanges
# Comments
# Repair Type                                    OEM
# TAT Days                                        21
# Price per ea (USD)                            4565
# pack_flag                                        0
# Service Count                                    1
# Name: 753, dtype: object

# %%
ChmData_new_flags.to_excel('GE_'+modelID+'_extracted_Data_flags_3.xlsx',index = None)
